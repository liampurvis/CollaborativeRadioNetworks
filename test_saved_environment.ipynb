# %% [markdown]
# # File loading demo:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ipywidgets import interact, widgets
import pickle
from os import listdir

def load_object(filename):
    with open(filename, 'rb') as  input:
        return pickle.load(input)

# %%
data = pd.DataFrame()

for experiment in listdir("saved_environments/"):
    for simulation in listdir("saved_environments/" + experiment + "/"):
        for player in load_object("saved_environments/" + experiment + "/" + simulation):
            data = pd.concat([data, pd.DataFrame([[experiment, simulation, 
                                                   player[0], player[1],
                                                   np.sum(player[2]), np.sum(player[2][1200:1500]), len(player[2])]], 
                                                 columns=["experiment_id", "simulation_id", 
                                                         "player_id", "player_type",
                                                         "player_success", "success_last_300_steps", "timesteps"])], 
                             axis = 0)
data
# Out:
#     experiment_id                simulation_id  player_id  \
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          0
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          1
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          2
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          3
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          4
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          5
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          6
# 0   CU_0000001_ns   result_CU_0000001_2_ns.pkl          8
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          0
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          1
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          2
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          3
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          4
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          5
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          6
# 0   CU_0000001_ns  result_CU_0000001_12_ns.pkl          8
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          0
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          1
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          2
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          3
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          4
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          5
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          6
# 0   CU_0000001_ns  result_CU_0000001_24_ns.pkl          8
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          0
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          1
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          2
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          3
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          4
# 0   CU_0000001_ns  result_CU_0000001_28_ns.pkl          5
# ..            ...                          ...        ...
# 0    CT_0111111_s   result_CT_0111111_11_s.pkl          6
# 0    CT_0111111_s   result_CT_0111111_11_s.pkl          7
# 0    CT_0111111_s   result_CT_0111111_11_s.pkl          8
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          0
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          1
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          2
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          3
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          4
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          5
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          6
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          7
# 0    CT_0111111_s   result_CT_0111111_15_s.pkl          8
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          0
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          1
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          2
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          3
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          4
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          5
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          6
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          7
# 0    CT_0111111_s   result_CT_0111111_28_s.pkl          8
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          0
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          1
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          2
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          3
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          4
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          5
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          6
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          7
# 0    CT_0111111_s   result_CT_0111111_17_s.pkl          8
#
#                   player_type  player_success  success_last_300_steps  \
# 0                        CSMA            2282                     200
# 0                        CSMA            2278                     196
# 0                        CSMA            1837                     121
# 0                        CSMA            2286                     200
# 0                        CSMA            2275                     200
# 0                        CSMA            2731                     105
# 0                         UCB            2785                      96
# 0   Simulating Non-Static Env            4916                     285
# 0                        CSMA            3172                      35
# 0                        CSMA            3172                      35
# 0                        CSMA            3177                      35
# 0                        CSMA            2292                      20
# 0                        CSMA            3169                      35
# 0                        CSMA            1831                     265
# 0                         UCB            1909                     267
# 0   Simulating Non-Static Env            4915                     295
# 0                        CSMA            2302                     247
# 0                        CSMA            2307                     247
# 0                        CSMA            1447                     126
# 0                        CSMA            2306                     247
# 0                        CSMA            2294                     247
# 0                        CSMA            2694                      56
# 0                         UCB            2966                      52
# 0   Simulating Non-Static Env            4909                     290
# 0                        CSMA            1796                     139
# 0                        CSMA            1784                     139
# 0                        CSMA            1788                     131
# 0                        CSMA            1559                     139
# 0                        CSMA            1792                     135
# 0                        CSMA            3205                     163
# ..                        ...             ...                     ...
# 0                   Thompsons             285                      68
# 0                         FIX             984                     214
# 0              Random Weights             606                      75
# 0                        CSMA             910                     192
# 0                   Thompsons             624                     160
# 0                   Thompsons             413                     152
# 0                   Thompsons             612                     229
# 0                   Thompsons             276                      73
# 0                   Thompsons             457                     186
# 0                   Thompsons             762                     288
# 0                         FIX             878                     181
# 0              Random Weights             518                      49
# 0                        CSMA             894                     178
# 0                   Thompsons             879                     231
# 0                   Thompsons             519                     241
# 0                   Thompsons             505                     212
# 0                   Thompsons             855                     291
# 0                   Thompsons             770                     246
# 0                   Thompsons             465                     208
# 0                         FIX            1060                     225
# 0              Random Weights             528                      23
# 0                        CSMA             874                     155
# 0                   Thompsons             266                      70
# 0                   Thompsons             284                      51
# 0                   Thompsons             323                      98
# 0                   Thompsons             803                     284
# 0                   Thompsons             879                     238
# 0                   Thompsons             600                     260
# 0                         FIX            1119                     225
# 0              Random Weights             742                     113
#
#     timesteps
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# 0        5000
# ..        ...
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
# 0        1500
#
# [16620 rows x 7 columns]

# %%
"""plt.hist(data.player_success[(data.player_type == "UCB") & 
                             (data.experiment_id.str.contains('UT'))]/data.timesteps[(data.player_type == "UCB") & 
                                                                                     (data.experiment_id.str.contains('UT'))],
         bins = 100)"""
"""import statsmodels
statsmodels.graphics.gofplots.qqplot(data.player_success[(data.player_type == "UCB") & 
                             (data.experiment_id.str.contains('UT'))]/data.timesteps[(data.player_type == "UCB") & 
                                                                                     (data.experiment_id.str.contains('UT'))])"""

#data = data.reset_index()

data['normalized_success'] = data.player_success/data.timesteps

# %%
data.loc[data.timesteps == 5000, ['player_type', 'player_success', 'timesteps', 'success_last_300_steps']].groupby('player_type').mean()
# Out:
#                            player_success  timesteps  success_last_300_steps
# player_type
# CSMA                          2112.794167     5000.0              121.650000
# Random                        1518.267500     5000.0               93.445833
# Simulating Non-Static Env     3043.547312     5000.0              188.145161
# Thompsons                     1942.412500     5000.0              116.978333
# UCB                           3143.166667     5000.0              185.006818
# UCB discounted                3590.584496     5000.0              222.222481

# %%
data.loc[data.timesteps == 5000, ['experiment_id', 
                                  'player_type', 
                                  'player_success', 
                                  'timesteps', 
                                  'success_last_300_steps']].groupby(['experiment_id', 
                                                                      'player_type']).mean()
# Out:
#                                           player_success  timesteps  \
# experiment_id  player_type
# CT_0000001_ns  CSMA                          2437.027778     5000.0
#                Simulating Non-Static Env     4925.033333     5000.0
#                Thompsons                     1982.933333     5000.0
# CT_000111_ns   CSMA                          2266.277778     5000.0
#                Simulating Non-Static Env     4019.633333     5000.0
#                Thompsons                     2244.855556     5000.0
# CT_0111111_ns  CSMA                          2387.966667     5000.0
#                Simulating Non-Static Env     3300.066667     5000.0
#                Thompsons                     1915.005556     5000.0
# CU_0000001_ns  CSMA                          2307.855556     5000.0
#                Simulating Non-Static Env     4926.600000     5000.0
#                UCB                           2982.133333     5000.0
# CU_000111_ns   CSMA                          2110.766667     5000.0
#                Simulating Non-Static Env     3944.033333     5000.0
#                UCB                           3555.277778     5000.0
# CU_0111111_ns  CSMA                          1430.933333     5000.0
#                Simulating Non-Static Env     3130.600000     5000.0
#                UCB                           3287.761111     5000.0
# CUd_0000001_ns CSMA                          2099.216667     5000.0
#                Simulating Non-Static Env     4931.000000     5000.0
#                UCB discounted                4439.466667     5000.0
# CUd_000111_ns  CSMA                          1322.055556     5000.0
#                Simulating Non-Static Env     4532.700000     5000.0
#                UCB discounted                4353.455556     5000.0
# CUd_0111111_ns CSMA                           315.700000     5000.0
#                Simulating Non-Static Env     4485.500000     5000.0
#                UCB discounted                3571.344444     5000.0
# RC_0000001_ns  CSMA                          1578.266667     5000.0
#                Random                        1429.588889     5000.0
#                Simulating Non-Static Env      614.700000     5000.0
# ...                                                  ...        ...
# UT_0000001_ns  Simulating Non-Static Env     1971.800000     5000.0
#                Thompsons                     2123.033333     5000.0
#                UCB                           3202.083333     5000.0
# UT_000111_ns   Simulating Non-Static Env     3534.866667     5000.0
#                Thompsons                     2149.677778     5000.0
#                UCB                           3907.922222     5000.0
# UT_0111111_ns  Simulating Non-Static Env     2903.800000     5000.0
#                Thompsons                     1996.205556     5000.0
#                UCB                           3966.633333     5000.0
# UUd_0000001_ns Simulating Non-Static Env     2177.900000     5000.0
#                UCB                           2911.066667     5000.0
#                UCB discounted                3589.566667     5000.0
# UUd_000111_ns  Simulating Non-Static Env     3868.700000     5000.0
#                UCB                           2871.544444     5000.0
#                UCB discounted                4060.522222     5000.0
# UUd_0111111_ns Simulating Non-Static Env     4115.133333     5000.0
#                UCB                           2509.266667     5000.0
#                UCB discounted                3173.172222     5000.0
# UdT_0000001_ns Simulating Non-Static Env     4117.900000     5000.0
#                Thompsons                     1563.133333     5000.0
#                UCB discounted                3264.122222     5000.0
# UdT_000111_ns  Simulating Non-Static Env     3596.100000     5000.0
#                Thompsons                     2058.311111     5000.0
#                UCB discounted                4115.244444     5000.0
# UdT_0111111_ns Simulating Non-Static Env     2912.700000     5000.0
#                Thompsons                     1892.183333     5000.0
#                UCB discounted                4107.300000     5000.0
# UdU_0001111_ns Simulating Non-Static Env     2580.333333     5000.0
#                UCB                           2613.108333     5000.0
#                UCB discounted                3711.755556     5000.0
#
#                                           success_last_300_steps
# experiment_id  player_type
# CT_0000001_ns  CSMA                                   147.416667
#                Simulating Non-Static Env              294.700000
#                Thompsons                              126.133333
# CT_000111_ns   CSMA                                   138.411111
#                Simulating Non-Static Env              224.900000
#                Thompsons                              135.000000
# CT_0111111_ns  CSMA                                   158.300000
#                Simulating Non-Static Env              221.566667
#                Thompsons                              122.827778
# CU_0000001_ns  CSMA                                   115.511111
#                Simulating Non-Static Env              296.066667
#                UCB                                    194.300000
# CU_000111_ns   CSMA                                   141.555556
#                Simulating Non-Static Env              229.533333
#                UCB                                    202.288889
# CU_0111111_ns  CSMA                                    72.000000
#                Simulating Non-Static Env              193.400000
#                UCB                                    194.700000
# CUd_0000001_ns CSMA                                   125.822222
#                Simulating Non-Static Env              295.133333
#                UCB discounted                         268.400000
# CUd_000111_ns  CSMA                                    63.166667
#                Simulating Non-Static Env              269.366667
#                UCB discounted                         261.433333
# CUd_0111111_ns CSMA                                    17.733333
#                Simulating Non-Static Env              267.933333
#                UCB discounted                         217.216667
# RC_0000001_ns  CSMA                                    76.933333
#                Random                                  84.572222
#                Simulating Non-Static Env               24.933333
# ...                                                          ...
# UT_0000001_ns  Simulating Non-Static Env              143.933333
#                Thompsons                              158.233333
#                UCB                                    186.122222
# UT_000111_ns   Simulating Non-Static Env              233.933333
#                Thompsons                              141.288889
#                UCB                                    238.888889
# UT_0111111_ns  Simulating Non-Static Env              186.733333
#                Thompsons                              115.222222
#                UCB                                    211.666667
# UUd_0000001_ns Simulating Non-Static Env              156.900000
#                UCB                                    173.000000
#                UCB discounted                         239.833333
# UUd_000111_ns  Simulating Non-Static Env              234.666667
#                UCB                                    171.300000
#                UCB discounted                         245.666667
# UUd_0111111_ns Simulating Non-Static Env              260.066667
#                UCB                                    133.400000
#                UCB discounted                         203.877778
# UdT_0000001_ns Simulating Non-Static Env              273.433333
#                Thompsons                               68.200000
#                UCB discounted                         215.400000
# UdT_000111_ns  Simulating Non-Static Env              212.166667
#                Thompsons                              115.933333
#                UCB discounted                         235.533333
# UdT_0111111_ns Simulating Non-Static Env              179.800000
#                Thompsons                              106.622222
#                UCB discounted                         243.166667
# UdU_0001111_ns Simulating Non-Static Env              172.266667
#                UCB                                    159.800000
#                UCB discounted                         239.822222
#
# [93 rows x 3 columns]

# %%
power = data.loc[data.timesteps == 5000, ['experiment_id', 
                                  'player_type', 
                                  'normalized_success']].groupby(['experiment_id', 
                                                                      'player_type']).var()
power['estimated_n'] = power.normalized_success * 9 /(.03**2)
max(power.estimated_n)
# Out:
# 436.17666022988533

# %%
data.loc[data.timesteps == 5000, ['experiment_id', 
                                  'player_type', 
                                  'player_success', 
                                  'timesteps', 
                                  'success_last_300_steps']].groupby(['experiment_id', 
                                                                      'player_type']).std()
